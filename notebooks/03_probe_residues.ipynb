# %% [markdown]
# # Probe Residues
#
# Run `collatz_lab.probes` first, then inspect probe metrics and plots.

# %%
import json
from pathlib import Path

probe_paths = list(Path('../reports').glob('*probe*.json'))
json.loads(probe_paths[-1].read_text()) if probe_paths else {}
