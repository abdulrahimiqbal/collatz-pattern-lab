# %% [markdown]
# # Evaluation Failures
#
# Inspect model errors by bit length, residue class, and height ratio.

# %%
import json
from pathlib import Path

metrics_paths = list(Path('../runs').glob('**/metrics.json'))
metrics = json.loads(metrics_paths[-1].read_text()) if metrics_paths else []
metrics[-3:] if metrics else metrics
