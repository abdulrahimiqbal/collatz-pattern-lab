# %% [markdown]
# # Dataset Sanity
#
# Load a generated shard and check exact labels against `collatz.py`.

# %%
from pathlib import Path
import pandas as pd
from collatz_lab.collatz import v2

paths = list(Path('../data').glob('**/*.parquet'))
df = pd.read_parquet(paths[0]) if paths else pd.DataFrame()
df.head()
